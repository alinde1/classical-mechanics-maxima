# %%
ratprint:false$ fpprintprec:5$ 
load(draw)$ load(ezunits)$ load(physical_constants)$
set_draw_defaults(draw_realpart=false,
  fill_color=gray50)$
# Out:
# ; compiling (DEFVAR $DRAW_RENDERER ...)
# ; compiling (DEFVAR $DRAW_USE_PNGCAIRO ...)
# ; compiling (DEFVAR *USER-GR-DEFAULT-OPTIONS* ...)
# ; compiling (DEFUN $SET_DRAW_DEFAULTS ...)
# ; compiling (DEFUN USER-DEFAULTS ...)
# ; compiling (DEFVAR *ALLOCATIONS* ...)
# ; compiling (DEFVAR *GR-OPTIONS* ...)
# ; compiling (DEFUN INI-GR-OPTIONS ...)
# ; compiling (DEFUN GET-OPTION ...)
# ; compiling (DEFUN ATOM-TO-DOWNCASED-STRING ...)
# ; compiling (DEFVAR *COLOR-TABLE* ...)
# ; compiling (SETF (GETHASH "snow" ...) ...)
# ; compiling (DEFUN CORRECT-COLOR-NAME ...)
# ; compiling (DEFUN CORRECT-COLOR-HEX ...)
# ; compiling (DEFUN CORRECT-COLOR ...)
# ; compiling (DEFUN HEX-TO-NUMERIC-LIST ...)
# ; compiling (DEFUN HEX-TO-RGB ...)
# ; compiling (DEFUN UPDATE-COLOR ...)
# ; compiling (DEFUN UPDATE-KEY_POS ...)
# ; compiling (DEFVAR *DRAW-TERMINAL-NUMBER* ...)
# ; compiling (DEFUN UPDATE-TERMINAL ...)
# ; compiling (DEFVAR *DRAW-TRANSFORM-DIMENSIONS* ...)
# ...
